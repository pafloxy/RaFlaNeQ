# %% [markdown]
# # Quantum Kernel Estimator Challenge
#
# For the first leg of the QML challenge, you implemented a variational quantum classifier (VQC) to take on a supervised learning problem based on the work of [Havlicek et al. (2018)](https://arxiv.org/pdf/1804.11326.pdf). Now, you will build on that experience, and explore Havlicek et al.'s second proposed method of applying quantum-enhanced feature spaces to machine learning: the *quantum kernel estimator*. In this challenge continuation, you will construct a QML model that estimates a kernel function using a quantum computer and optimize a classical support vector machine (SVM). For this classification protocol, we will continue to restrict ourselves to the binary label case, with $C = \left\{+1, −1\right\}$.
#
# Compared to the VQC challenge, we are providing very little template code for this kernel estimator challenge. This is by design to enable teams to further differentiate their model, especially in the training phase. The [Havlicek et al. (2018)](https://arxiv.org/pdf/1804.11326.pdf) paper is your best resource, and the [Kernel-based training Pennylane tutorial](https://pennylane.ai/qml/demos/tutorial_kernel_based_training.html) may also be helpful. You are free to import and use any additional packages that you wish.

# %%
#!qbraid jobs enable haqs  # enable quantum jobs

# %%
TEAM_NAME = "RaFlaNeQ"  # enter team name

# %%
import warnings

warnings.filterwarnings("ignore")

import csv
import json
import os
import time
from itertools import chain, combinations

import matplotlib.lines as mlines
import matplotlib.pyplot as plt
import qiskit
from qiskit.visualization import plot_histogram
import pennylane as qml
import pennylane.numpy as np
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

from scipy.optimize import minimize

 
import cvxopt as opt
from cvxopt import matrix, spmatrix, sparse
from cvxopt.solvers import qp, options
from cvxopt import blas

from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Load and visualize dataset
#
# As before, we are given data from a training set $T$ and a test set $S$ of a subset $\Omega \in \rm {I\!R}^n$. Both are assumed to be labelled by the map $m: T \cup S \rightarrow \{+1, −1\}$ unkown to the algorithm. To generate the data, two random vectors in the X-Z plane of the Bloch sphere are chosen. Around these two vectors, we randomly sample two sets of quantum data points; the task is to learn to distinguish the two sets.

# %%
# %run gen_binary.py  # uncomment to generate new train/test dataset

# %%
DATA_PATH = "data/"

file = open(DATA_PATH + "params.json")

params = json.load(file)
delta = params["delta"]
n_points = params["n_points"]

file.close()

# Load data
Xs = np.zeros(shape=(n_points, 2))
Ys = np.zeros(shape=(n_points,))

with open(DATA_PATH + "binary_data.csv", mode="r") as file:
    csvFile = csv.reader(file)
    for i, row in enumerate(csvFile):
        Xs[i] = np.array([float(row[0]), float(row[1])])
        Ys[i] = float(row[2])
        if i == n_points:
            break

n_sets = 2
samples_per_set = 40
n_samples = n_sets * samples_per_set
X_data, Y_data = Xs[:n_samples], Ys[:n_samples]
X_train, X_test, Y_train, Y_test = train_test_split(
    X_data, Y_data, train_size=1 / n_sets
)

# %%
split_xs = lambda x: [[x[i][j] for i in range(len(x))] for j in [0, 1]]

xi, xj = split_xs(Xs)
xi_train, xj_train = split_xs(X_train)
xi_test, xj_test = split_xs(X_test)

label_circle = mlines.Line2D(
    [],
    [],
    color="none",
    marker="o",
    markerfacecolor="none",
    markeredgecolor="black",
    label=f"Train ({len(X_train)})",
)
label_square = mlines.Line2D(
    [],
    [],
    color="none",
    marker="s",
    markerfacecolor="none",
    markeredgecolor="black",
    label=f"Test ({len(X_test)})",
)

plt.scatter(xi, xj, marker="o", c=["r" if v == 1.0 else "b" for v in Ys])
plt.scatter(xi_train, xj_train, c=["k" if v == 1.0 else "y" for v in Y_train])
plt.scatter(xi_test, xj_test, marker="s", c=["k" if v == 1.0 else "y" for v in Y_test])
plt.xticks([0, 2 * np.pi], [r"$0$", r"$2\pi$"])
plt.yticks([0, 2 * np.pi], [r"$0$", r"$2\pi$"])
plt.xlabel("$\\theta$")
plt.ylabel("$\phi$")
plt.legend(handles=[label_circle, label_square], loc="upper right")
plt.title(f"Classification Data, $\Delta = {delta}$")
plt.show()

# %% [markdown]
# An arbitrary single qubit state can be written:
#
# $$ \left| \psi \right\rangle = e^{i \gamma} \big(\cos \frac{\theta}{2}\left|0\right\rangle + e^{i \phi} \sin \frac{\theta}{2}\left|1\right\rangle \big) $$
#
# where $\theta$, $\phi$ and $\gamma$ are real numbers. The numbers $0 \leq \theta \leq \pi$ and $0 \leq \phi \leq 2\pi$ define a point on the Bloch sphere.

# %%
def powerset(iterable, mx):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    pset = chain.from_iterable(combinations(s, r) for r in range(len(s) + 1))
    return [l for l in list(pset) if len(l) == mx]

# %%
def encode_data(x):
    """Non-linear encoding (transformation) of one input data vector

    Args:
        x : shape (2,) tensor containing one input data vector

    Returns:
        triple of data encoded coefficients phi_1, phi_2, phi_{1,2}
    """

    return x[0], x[1], (np.pi - x[0]) * (np.pi - x[1])

# %% [markdown]
# Considering only Ising type interactions ($d=2$), the unitaries are generated from one- and two- big gates of the form
#
# $$U_{\phi_{\{k\}}(\textbf{x})} = \exp\big(i\phi_{\{k\}}(\textbf{x})Z_k \big)$$
# $$U_{\phi_{\{l,m\}}(\textbf{x})} = \exp\big(i\phi_{\{k,l\}}(\textbf{x})Z_kZ_l\big)$$
#
# where we have followed Havlíček et al. and chosen $\phi_{\{ i \}} = x_i$ and $\phi_{\{ 1,2 \}} = (\pi - x_1)(\pi - x_2)$

# %%
# functionality within the class as a attribute.
n_wires = 2  # number of qubits
S_size = 2  # number of interactions considered
pset = powerset(range(n_wires), S_size)

# %%
def embedding(x):
    """The embedding ansatz

    Args:
        x : shape (3,) tensor containing one encoded data vector

    """
    ## @pafloxy 
    for w in range(n_wires):
        qml.RZ(2 * x[w], wires= w)
    for w in pset:
        qml.CNOT(wires= w)
        qml.RZ(2 * x[2], wires= w[1])    
        qml.CNOT(wires= w)

# %% [markdown]
# ## Quantum kernel (ideal)

# %%
dev_kernel = qml.device("default.qubit", wires=n_wires)

projector = np.zeros((2**n_wires, 2**n_wires))
projector[0, 0] = 1


@qml.qnode(dev_kernel)
def kernel(x, z):
    """Compute quantum kernel element for two feature vectors.

    Args:
        x : shape (2,) tensor containing one input data vector
        z : shape (2,) tensor containing one input data vector
    
    Returns: |<0|feature_map(z)^daggered feature_map(x)|0>|^2 calculated via mat multiplication 

    """

    x_enc = encode_data(x)
    z_enc = encode_data(z)

    for _ in range(S_size):
        for i in range(n_wires):
            qml.Hadamard(wires=i)
        embedding(x_enc)

    for _ in range(S_size):
        qml.adjoint(embedding)(z_enc)
        for i in range(n_wires):
            qml.Hadamard(wires=i)

    return qml.expval(qml.Hermitian(projector, wires=range(n_wires)))

# %%
def kernel_ideal(A, B):
    """Ideal kernel matrix for sets A and B."""
    return np.array([[kernel(a, b) for b in B] for a in A])

# %%
# evaluate k_ideal
# takes about a minute or two to evaluate completely
k_ideal = kernel_ideal(X_train, X_train)

# %%
# Visualize ideal kernel matrix containing the inner products of all
# data points used for training, c.f. Havlicek Fig. 4.a (right)
im = plt.imshow(k_ideal, extent=(0, samples_per_set, 0, samples_per_set))
plt.colorbar(im)
plt.xticks([0, samples_per_set])
plt.yticks([0, samples_per_set])
plt.title("$K$ (ideal)")
plt.show()

# %% [markdown]
# Ideally kernel matrix must be a positive semi-definite matrix ($\implies$ all its eigenvalues must be $\geq$ 0). However, either due to numerical error (in numerical simulations) or due to insufficient number of sampling (while obtaining kernel from by running the quantum circuit on an actual quantum hardware), it might not be exactly positive semi-definite. Below we investigate the same as follows:
#
# 1. We found those eigenvalues of kernel matrix *kernel_ideal* which are negative.
# 2. We then checked the magnitude of most negative eigenvalue.
#
# Existence of negative eigen-values, though of very low magnitude, indicates that k_ideal is only approximately postive-definite, compared to machine-precision

# %%
## check properties of ideal kernel-matrix
negative_eigs = np.array([ np.linalg.eigvals(k_ideal)[i] for i in range(len(k_ideal)) if np.linalg.eigvals(k_ideal)[i] < 0 ])
max(np.abs(np.real(negative_eigs))), len(negative_eigs)
# Out:
# (tensor(5.45387377e-16, requires_grad=True), 10)

# %% [markdown]
# ## Quantum kernel estimator

# %% [markdown]
# Here it will be convenient to write $T = \left\{\textbf{x}_1,...,\textbf{x}_t\right\}$ with $t = \left|T\right|$; also let $y_i = m(\textbf{x}_i)$ be the corresponding label. In this protocol you will use a quantum computer to estimate the $t \times t$ kernel matrix $K(\textbf{x}_i, \textbf{x}_j) = \left|\langle\Phi(\textbf{x}_i)|\Phi(\textbf{x}_j)\rangle\right|^2$. For all pairs of points $\textbf{x}_i, \textbf{x}_j \in T$ in the the training data, you will sample the overlap between feature states to obtain the matrix entry in the kernel. This fidelity can be estimated from the output probability of the circuit by sampling the output distribution with $R$ shots and only taking the $0^n$ count. The frequency of the $0^n$ count is an estimator of the Kernel entry up to an error $\epsilon = O(R^{−1/2})$. After the kernel matrix for the full training data has been constructed we use the conventional (classical) support vector machine classifier. The optimal hyperplane can be found by solving the dual quadratic program $L_D$ for the variables $\alpha = \left\{\alpha_i\right\}_{i=1...t}$. Hence, to train, we maximize
#
# \begin{equation}
# L_D(\alpha) = \sum_{i=1}^t \alpha_i - \frac{1}{2} \sum_{i,j=1}^t y_i y_j \alpha_i \alpha_j K(\textbf{x}_i, \textbf{x}_j),
# \label{eq:Ld} \tag{1}
# \end{equation}
#
# subject to $\sum_{i=1}^t \alpha_i y_i = 0$ and $\alpha_i \geq 0$. This problem is concave, and therefore efficiently solvable, whenever $K(\textbf{x}_i, \textbf{x}_j)$ is a positive definite matrix. Standard quadratic programming solvers can be used. The solution to this problem will be given by a nonnegative vector $\alpha^* = (\alpha_1^*,...,\alpha_t^*)$. Due to complementary slackness, we expect that many of the $\alpha_i^*$ will be zero. Hence, there will only be subset of training samples that are needed to construct the optimal hyperplane. These samples are referred to as the support vectors.
#
# The training phase consists of the following steps:
#
# ---
# ### Algorithm 1: training
# 1. **Input** Labeled training samples $T = \left\{ \textbf{x} \in \Omega \in {\rm I\!R}^n \right\} \times \left\{ y \in C \right\}$, quadratic program solver.
# 2. **Parameters** Number of measurement shots $R$.
# 3. Calibrate the quantum hardware to generate short depth circuits.
# 4. **for** $\textit{i} = 1$ to $\textit{t}$ **do**
# 5. $\hspace{5mm}$ **for** $\textit{j} = 1$ to $\textit{t}$ **do**
# 6. $\hspace{10mm}$ Set the counter $r_{0^n} = 0$
# 7. $\hspace{10mm}$ **for** $\textit{shot} = 1$ to $R$ **do**
# 8. $\hspace{15mm}$ Run the circuit from Havlicek Fig. 2.c. with paremeters $\textbf{x}_i, \textbf{x}_j$.
# 9. $\hspace{15mm}$ Measure outcome in $Z$-basis.
# 10. $\hspace{15mm}$ **if** Measurement outcome is $0^n$ **then**
# 11. $\hspace{20mm}$ Increase counter by one, setting $r_{0^n} \rightarrow r_{0^n} + 1$.
# 12. $\hspace{15mm}$ **end if**
# 13. $\hspace{10mm}$ **end for**
# 14. $\hspace{10mm}$ Construct kernel estimate $\hat{K}(\textbf{x}_i, \textbf{x}_j) = r_{0^n}R^{-1}$.
# 15. $\hspace{5mm}$ **end for**
# 16. **end for**
# 17. Use quadratic program solver to optimize $\alpha$ in $L_D$ in eqn. (1) with kernel $K = \hat{K}$ and set $T$.
# 18. **return** the final parameters $\alpha^*$ and value of the cost function $L_D$ and kernel estimator $\hat{K}$.
# ---

# %%
shots=1000

# %%
device_arn = "arn:aws:braket:::device/quantum-simulator/amazon/sv1"                     # SV1
#device_arn = AwsDevice('arn:aws:braket:::device/quantum-simulator/amazon/dm1')            #DM1
# device = AwsDevice('arn:aws:braket:::device/qpu/ionq/ionQdevice')                     #IonQ
# device = AwsDevice('arn:aws:braket:::device/qpu/rigetti/Aspen-11')                    #Rigetti Aspen-11
# device = AwsDevice('arn:aws:braket:us-west-1::device/qpu/rigetti/Aspen-M-2')          #Rigetti Aspen M-2

dev_remote = qml.device(
    "braket.aws.qubit",
    device_arn=device_arn,
    wires=20,
    parallel=True,
    max_parallel=20,
    shots=shots,
)

#qnode_remote = qml.QNode(circuit, dev_remote)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In [64], line 7
#       1 device_arn = "arn:aws:braket:::device/quantum-simulator/amazon/sv1"                     # SV1
#       2 #device_arn = AwsDevice('arn:aws:braket:::device/quantum-simulator/amazon/dm1')            #DM1
#       3 # device = AwsDevice('arn:aws:braket:::device/qpu/ionq/ionQdevice')                     #IonQ
#       4 # device = AwsDevice('arn:aws:braket:::device/qpu/rigetti/Aspen-11')                    #Rigetti Aspen-11
#       5 # device = AwsDevice('arn:aws:braket:us-west-1::device/qpu/rigetti/Aspen-M-2')          #Rigetti Aspen M-2
# ----> 7 dev_remote = qml.device(
#       8     "braket.aws.qubit",
#       9     device_arn=device_arn,
#      10     wires=20,
#      11     parallel=True,
#      12     max_parallel=20,
#      13     shots=shots,
#      14 )
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/pennylane/__init__.py:320, in device(name, *args, **kwargs)
#     314     raise DeviceError(
#     315         f"The {name} plugin requires PennyLane versions {plugin_device_class.pennylane_requires}, "
#     316         f"however PennyLane version {__version__} is installed."
#     317     )
#     319 # Construct the device
# --> 320 dev = plugin_device_class(*args, **options)
#     322 # Once the device is constructed, we set its custom expansion function if
#     323 # any custom decompositions were specified.
#     324 if custom_decomps is not None:
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/braket/pennylane_plugin/braket_device.py:321, in BraketAwsQubitDevice.__init__(self, wires, device_arn, s3_destination_folder, shots, poll_timeout_seconds, poll_interval_seconds, aws_session, parallel, max_parallel, max_connections, max_retries, **run_kwargs)
#     305 def __init__(
#     306     self,
#     307     wires: Union[int, Iterable],
#    (...)
#     319     **run_kwargs,
#     320 ):
# --> 321     device = AwsDevice(device_arn, aws_session=aws_session)
#     322     user_agent = f"BraketPennylanePlugin/{__version__}"
#     323     device.aws_session.add_braket_user_agent(user_agent)
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/braket/aws/aws_device.py:81, in AwsDevice.__init__(self, arn, aws_session)
#      79 self._topology_graph = None
#      80 self._type = None
# ---> 81 self._aws_session = self._get_session_and_initialize(aws_session or AwsSession())
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/braket/aws/aws_device.py:231, in AwsDevice._get_session_and_initialize(self, session)
#     226 def _get_session_and_initialize(self, session: AwsSession) -> AwsSession:
#     227     device_region = AwsDevice.get_device_region(self._arn)
#     228     return (
#     229         self._get_regional_device_session(session)
#     230         if device_region
# --> 231         else self._get_non_regional_device_session(session)
#     232     )
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/braket/aws/aws_device.py:259, in AwsDevice._get_non_regional_device_session(self, session)
#     257             raise ValueError(f"Simulator '{self._arn}' not found in '{current_region}'")
#     258     else:
# --> 259         raise e
#     260 # Search remaining regions for QPU
#     261 for region in frozenset(AwsDevice.REGIONS) - {current_region}:
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/braket/aws/aws_device.py:252, in AwsDevice._get_non_regional_device_session(self, session)
#     250 current_region = session.region
#     251 try:
# --> 252     self._populate_properties(session)
#     253     return session
#     254 except ClientError as e:
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/braket/aws/aws_device.py:272, in AwsDevice._populate_properties(self, session)
#     271 def _populate_properties(self, session: AwsSession) -> None:
# --> 272     metadata = session.get_device(self._arn)
#     273     self._name = metadata.get("deviceName")
#     274     self._status = metadata.get("deviceStatus")
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/braket/aws/aws_session.py:598, in AwsSession.get_device(self, arn)
#     588 def get_device(self, arn: str) -> Dict[str, Any]:
#     589     """
#     590     Calls the Amazon Braket `get_device` API to retrieve device metadata.
#     591
#    (...)
#     596         Dict[str, Any]: The response from the Amazon Braket `GetDevice` operation.
#     597     """
# --> 598     return self.braket_client.get_device(deviceArn=arn)
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/botocore/client.py:514, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     510     raise TypeError(
#     511         f"{py_operation_name}() only accepts keyword arguments."
#     512     )
#     513 # The "self" in this scope is referring to the BaseClient.
# --> 514 return self._make_api_call(operation_name, kwargs)
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/botocore/client.py:938, in BaseClient._make_api_call(self, operation_name, api_params)
#     936     error_code = parsed_response.get("Error", {}).get("Code")
#     937     error_class = self.exceptions.from_code(error_code)
# --> 938     raise error_class(parsed_response, operation_name)
#     939 else:
#     940     return parsed_response
#
# ClientError: An error occurred (UnrecognizedClientException) when calling the GetDevice operation: The security token included in the request is invalid.

# %%
#shots= 1000
dev_local = qml.device('default.qubit', wires=n_wires, shots= shots)

#@qml.qnode(dev_remote)
@qml.qnode(dev_local)
def fidelity_estimate_circuit(x, z):
    
    """Circuit to estimate the fidelity between a pair of feature vectors for data `x` and `z`

    Args:
        x : shape (2,) tensor containing one input data vector
        z : shape (2,) tensor containing one input data vector

    """

    # TODO (hint: Havlicek Fig. 2.c.)

    x_enc = encode_data(x)
    z_enc = encode_data(z)

    for _ in range(S_size):
        for i in range(n_wires):
            qml.Hadamard(wires=i)
        embedding(x_enc)

    for _ in range(S_size):
        qml.adjoint(embedding)(z_enc)
        for i in range(n_wires):
            qml.Hadamard(wires=i)
    
    #return qml.probs(wires=[0,1])
    return qml.counts(all_outcomes=True)

def fidelity_estimate(x,z):
    """Estimate the fidelity between a pair of feature vectors for data `x` and `z`

    Args:
        x : shape (2,) tensor containing one input data vector
        z : shape (2,) tensor containing one input data vector

    """

    counts=fidelity_estimate_circuit(x,z)
    all_zero='0'*n_wires
    prob_all_zero=counts[all_zero]/shots
    return prob_all_zero# return empirical probability of sampling 00..0

# %%
def kernel_experimental(A, B):
    """Experimentally estimated kernel matrix for sets A and B."""
    return np.array([[fidelity_estimate(i, j) for j in B] for i in A])

# %%
# example run
fidelity_estimate(X_train[0,:],X_train[1,:])
# Out:
# 0.019

# %%
# estimate kernel matrix experimentally (by sampling all zero states, c.f. Havlicek Fig. 2.c. )
k_experimental = kernel_experimental(X_train, X_train)

# Visualize experimental kernel matrix containing the inner products of all
# data points used for training, c.f. Havlicek Fig. 4.a (left)
im = plt.imshow(k_experimental, extent=(0, samples_per_set, 0, samples_per_set))
plt.colorbar(im)
plt.xticks([0, samples_per_set])
plt.yticks([0, samples_per_set])
plt.title("$\hat{K}$ (experimental)")
plt.show()

# %% [markdown]
# Similarly here we check the corresponding properties of the kernel obtained from the experiment,

# %%
## check properties of experimental kernel-matrix
negative_eigs = np.array([ np.linalg.eigvals(k_experimental)[i] for i in range(len(k_experimental)) if np.linalg.eigvals(k_experimental)[i] < 0 ])
min(np.abs(np.real(negative_eigs))), len(negative_eigs) ## existence of low magnitude negative eigen-values indicate that k_experimental is only approximately postive-definite, compared to machine-precision
# Out:
# (tensor(0.00189427, requires_grad=True), 12)

# %% [markdown]
# ##### **Checking differences betwenn $\mathbf{\hat{K}_{ideal}}$ and $ \mathbf{\hat{K}_{exp}}$**

# %% [markdown]
# Next we make an comparison between the ideal kernel `k_ideal` and `k_experimental`, by checking the properties of the *Frobenius Inner Product* of their difference
#
# $$                      \mathbf{f(\hat{K}_{ideal}-\hat{K}_{exp})} = \mathbf{Tr}\left( \left(\hat{K}_{ideal}-\hat{K}_{exp}\right)^{T}\left(\hat{K}_{ideal}-\hat{K}_{exp}\right) \right)
# $$
#
# Lower the value of **f**, closer the both matrices are to each other. Also we can check the magnitude of the largest eigenvalue of $\mathbf{\hat{K}_{ideal}-\hat{K}_{exp}}$, which should be close to zero if the matrices match up to certain degree.

# %%
## Compare k_experimental against k_ideal
diff = k_experimental - k_ideal
qml.math.frobenius_inner_product(diff,diff) , np.real(np.linalg.eigvals(diff))[0]  ## check the frobenius norm of the 'diff' as well as its largest eigenvalue
# Out:
# (tensor(0.23340976, requires_grad=True),
#  tensor(0.04322604, requires_grad=True))

# %%
im = plt.imshow(diff, extent=(0, samples_per_set, 0, samples_per_set))
plt.colorbar(im)
plt.xticks([0, samples_per_set])
plt.yticks([0, samples_per_set])
plt.title("difference")
plt.show()

# %% [markdown]
# We can also reproduce the plots from the original **Havelick** paper where we directly compare the rows of the kernel matrix.

# %%
j = 5 ## choose any row for comparing 
plot_histogram([dict([ ('j'+ str(i), k_ideal[j,i]) for i in range(len(k_ideal[j]))  ]) ,dict([ ('j'+ str(i), k_experimental[j,i]) for i in range(len(k_ideal[j]))  ])], figsize= (15,7) , legend= ['ideal', 'exp'],sort= 'desc',bar_labels=False, title= "$\mathbf{\hat{K}_{j}}$")

# %% [markdown]
# For the next phase of the problem, we are required to frame an quadratic optimisation problem $\mathbf{L_{D}}$ in terms of the parameters $\mathbf{ \{ \alpha_1, \alpha_2, . . .\alpha_n \} }$, basing which we can proceed to classify any given data. For that purpose we design the `support_vector_classifier` class which can be used to find the optimal set $\mathbf{ \{\alpha_i \}}$ as well as to predict on any given input.

# %%
from typing import Callable# might be deprecated for the latest version. 
class support_vector_classifier():
    """
    A class to aid the Support Vector Classifier. 

    ARGS:
    ----
    fidelity_calc_fun: a function that can calculate the fidelity of two given data vectors


    The following class has the class-methods for the following : 'find_kernel_matrix' , 'train_svc' , 'preict_svc', thus providing
    an end-to-end solution to the task of traing and testing the Support Vector Classifier.
    
    """

    def __init__(self, fidelity_calc_fun: Callable ) -> None :
        
        self.fidelity_estimate = fidelity_calc_fun 
    
    def find_kernel_matrix(self, A, B) -> np.array :
        """ 
        Calculates elements of the kernel matrix for the given inputs
        """

        return np.array([[self.fidelity_estimate(i, j) for j in B] for i in A])
        

    def train_svc(self, x_train: np.array, y_train: np.array, c: float = 0.00001):
        """
        Formulates the Dual problem to find necessary support coefficents -> alphas,  and then solves it using 'cvxopt' tools.
        Refer to https://www.cvxpy.org/examples/basic/quadratic_program.html for more details.

        ARGS:
        ----
        x_train : an array containing all training data (X)
        y_train : an array containing all training labels (Y)
        c : numerical-zero for support vectors, alphas with value less than 'c' are excluded from the support


        RETURNS:
        -------
        support_vec_indices : array containing indices of the 'x_train' that correspond to the support vectors
        support_vec_alphas : array of positive 'alpha' coefficient corresponding to the support vectors 
        support_vec_ : array of support vectors
        b_estimates : estimate 'b' parameter for the classification step
        
        """
        ## load trainig data ##
        self.x_train = x_train
        self.y_train = y_train
        self.training_set_size = len(y_train)

        n = self.training_set_size

        self.kernel_matrix = self.find_kernel_matrix(x_train, x_train)
        quadratic_term = np.zeros((n,n))

        # print(self.kernel_matrix) ## checkflag

        ## formulate quadratic problem ##
        for i in range(n):
            for j in range(n):
                quadratic_term[i,j] = self.kernel_matrix[i,j] * self.y_train[i] * self.y_train[j]

        quadratic_term = (0.5) * quadratic_term     ## quadrtic term
        linear = -1 * np.ones(n)        ## linear term

        A = matrix(self.y_train).T  ## add equality-constraints ; 
        B = matrix(0.0)
        G = matrix(-1* np.eye(n))  ## add positivity-constraints ; all alpha's should be positive 
        H = matrix(np.zeros(n))

        sol = qp(matrix(quadratic_term), matrix(linear), G, H, A, B)

        alphas = np.array(sol['x'])

        ## extract information regarding support vectors ##
        self.support_vec_indices = [ i for i in range(len(alphas)) if alphas[i] > c]
        self.support_vec_alphas =  [ (i, alphas[i]) for i in range(len(alphas)) if alphas[i] > c ] 
        self.support_vec_ =  [ (i, self.x_train[i]) for i in range(len(alphas)) if alphas[i] > c ] 
        
        ## estimate 'b' parameter for the classifier ##
        b_estimates = [y_train[j] - np.sum([ self.y_train[i] * alphas[i] * self.fidelity_estimate(self.x_train[i] , self.x_train[j]) for i in range(n)]) for j in self.support_vec_indices] 
        self.b = np.mean(b_estimates)

        return self.support_vec_indices, self.support_vec_alphas, self.support_vec_, b_estimates

    def predict_svc(self, x_test_elem: np.array):
        """ 
        Function to predict class of given input 

        ARGS:
        ----
        x_test_elem  :  single input data 

        
        RETURNS:
        -------
        y_label_elem :  predicted binary label

        """
        estimate = np.sum([  self.y_train[index] * alpha * self.fidelity_estimate(self.x_train[index], x_test_elem) for index, alpha in self.support_vec_alphas ]) + self.b
        y_label_elem = np.sign(estimate)

        return y_label_elem

# %% [markdown]
# We train the `support_vector_classifier` on both the ideal and the experimental kernel calculating functions and use them to make predictions on the test set.

# %%
svc_exp = support_vector_classifier(fidelity_estimate) ## train using experimental kernel estimator
res_exp = svc_exp.train_svc(X_train, Y_train)

prediction_exp = [(svc_exp.predict_svc(X_test[j]) == Y_test[j] ) for j in range(len(Y_test))]
acc_exp = prediction_exp.count(True) / len(Y_test) * 100
print(f"Prediction accuracy is: {acc_exp}%.")  ## takes around 2 min
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -9.1596e+00 -3.1198e+01  1e+02  6e+00  2e+00
#  1: -1.3721e+01 -3.5439e+01  3e+01  8e-01  3e-01
#  2: -1.8148e+01 -3.1497e+01  1e+01  3e-01  1e-01
#  3: -2.2884e+01 -2.6383e+01  4e+00  3e-02  1e-02
#  4: -2.3845e+01 -2.5082e+01  1e+00  1e-02  4e-03
#  5: -2.4311e+01 -2.4673e+01  4e-01  9e-04  3e-04
#  6: -2.4500e+01 -2.4537e+01  4e-02  9e-05  3e-05
#  7: -2.4522e+01 -2.4522e+01  6e-04  9e-07  3e-07
#  8: -2.4522e+01 -2.4522e+01  7e-06  9e-09  3e-09
# Optimal solution found.
# Prediction accuracy is: 100.0%.

# %%
svc_ideal = support_vector_classifier(kernel) ## train using ideal kernel estimator
res_ideal = svc_ideal.train_svc(X_train, Y_train)

prediction_ideal = [(svc_ideal.predict_svc(X_test[j]) == Y_test[j] ) for j in range(len(Y_test))]
acc_ideal = prediction_ideal.count(True) / len(Y_test) * 100
print(f"Prediction accuracy is: {acc_ideal*1}%.")   ## takes around 2 min
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -9.7645e+00 -3.0135e+01  9e+01  7e+00  2e+00
#  1: -1.2908e+01 -3.0061e+01  2e+01  1e+00  3e-01
#  2: -1.6260e+01 -2.2684e+01  7e+00  1e-01  4e-02
#  3: -1.8761e+01 -2.0054e+01  1e+00  1e-02  4e-03
#  4: -1.9485e+01 -1.9628e+01  1e-01  9e-04  3e-04
#  5: -1.9570e+01 -1.9577e+01  7e-03  4e-05  1e-05
#  6: -1.9575e+01 -1.9575e+01  1e-04  5e-07  2e-07
#  7: -1.9575e+01 -1.9575e+01  2e-06  5e-09  2e-09
# Optimal solution found.
# Prediction accuracy is: 100.0%.

# %% [markdown]
# We also compare the classification accuracy obtained by us against the `sklearn.svm`'s `SVC` module which has inbuilt funtionaliteis to train and predict.

# %%
svc_sklrn = SVC(kernel= kernel_ideal, C = 100000.0)
svc_sklrn = svc_sklrn.fit(X_train, Y_train)

prediction_sklrn = svc_sklrn.predict(X_test)
prediction_sklrn = [ prediction_sklrn[i]==Y_test[i] for i in range(len(Y_test))]
acc_sklrn = prediction_sklrn.count(True) / len(Y_test) * 100
print(f"Prediction accuracy is: {acc_sklrn}%.")    ## takes around 3 min
# Out:
# Prediction accuracy is: 100.0%.

# %% [markdown]
# In the classification phase, we want to assign a label to a new datum $s \in S$ of the test set. For this, the inner products $K(\textbf{x}_i, \textbf{s})$ between all support vectors $\textbf{x}_j \in T$ with $\alpha_i^* > 0$ and the new datum s have to be estimated on the quantum computer, c.f. Havlicek Fig. S5.b. The new label $\tilde{m}(\textbf{s})$ for the datum is assigned according to Havlicek eqn. (14). Since all support vectors are known from the training phase and we have obtained access to the kernel $K(\textbf{x}_i,\textbf{s})$ from the quantum hardware, the label can be directly computed according to
#
#
# $$\begin{equation}
# \tilde{m}(\textbf{s}) = \text{sign} \bigg(\sum_{i=1}^t y_i \alpha_i^* K(\textbf{x}_i, \textbf{s}) + b \bigg).
# % \label{eq:ms} \tag{2}
# \end{equation}$$
#
# Note that the bias $b$ in $\tilde{m}(\textbf{s})$ can be calculated from the weights $\alpha_i^*$ by choosing any $i$ with $\alpha_i^* > 0$ and solving $\sum_j y_j \alpha_j^* K(\textbf{x}_j, \textbf{x}_i) + b = y_i$ for $b$.
#
# ---
# ### Algorithm 2: classification
# 1. **Input** An unlabeled sample from the test set $\textbf{s} \in S$, optimal SVM parameters $\alpha, b$ and training data set $T$.
# 2. **Parameters** Number of measurement shots $R$.
# 3. Calibrate the quantum hardware to generate short depth circuits.
# 4. **for** $\textit{i} = 1$ to $\textit{t}$ with $\alpha_i^* > 0$ **do**
# 5. $\hspace{5mm}$ Set the counter $r_{0^n} = 0$
# 7. $\hspace{5mm}$ **for** $\textit{shot} = 1$ to $R$ **do**
# 8. $\hspace{10mm}$ Run the circuit from Havlicek Fig. 2.c. with paremeters $\textbf{x}_i, \textbf{s}$.
# 9. $\hspace{10mm}$ Measure outcome in $Z$-basis.
# 10. $\hspace{10mm}$ **if** Measurement outcome is $0^n$ **then**
# 11. $\hspace{15mm}$ Increase counter by one, setting $r_{0^n} \rightarrow r_{0^n} + 1$.
# 12. $\hspace{10mm}$ **end if**
# 13. $\hspace{5mm}$ **end for**
# 14. $\hspace{5mm}$ Construct kernel estimate $\hat{K}(\textbf{x}_i, \textbf{s}) = r_{0^n}R^{-1}$.
# 15. **end for**
# 16. **return** $\text{sign}\big(\sum_{i=1}^t y_i \alpha_i^* \hat{K}(\textbf{x}_i, \textbf{s}) + b \big)$.
# ---

# %% [markdown]
# ##### **Prediction Accuracy**

# %%
preds = prediction_exp   # change with { prediction_exp, prediction_sklrn , prediction_ideal}
n_correct = preds.count(True)
n_incorrect = preds.count(False)

# Plot predictions
# preds_png = f"{VQC_OUT}/{TEAM_NAME}_preds.png"

label_correct = mlines.Line2D(
    [],
    [],
    color="none",
    marker="o",
    markerfacecolor="g",
    markeredgecolor="y",
    label=f"correct ({n_correct})",
)
label_incorrect = mlines.Line2D(
    [],
    [],
    color="none",
    marker="o",
    markerfacecolor="k",
    markeredgecolor="k",
    label=f"incorrect ({n_incorrect})",
)

plt.figure(figsize=(16,9))
plt.scatter(xi, xj, marker="o", c=["r" if v == 1 else "cyan" for v in Ys])
plt.scatter(xi_test, xj_test, c=["y" if v == True else "k" for v in preds])
plt.xticks([0, 2 * np.pi], [r"$0$", r"$2\pi$"])
plt.yticks([0, 2 * np.pi], [r"$0$", r"$2\pi$"])
plt.xlabel("$\\theta$")
plt.ylabel("$\phi$")
plt.legend(handles=[label_correct, label_incorrect], loc="upper right")
plt.title(f"Predictions, $\Delta = {delta}$")
# plt.savefig(preds_png)
plt.show()

# %% [markdown]
# ##### **Support Vectors**

# %% [markdown]
# We can also compare the support vectors found by each of the three methods discussed above. Below we return the index of the training vectors in the input data set that form the support. Usually most of the support vectors will be the same with a few exceptions

# %%
## return indices of vectors in 'X_train' that forms the support ##
set(svc_sklrn.support_), set(res_ideal[0]), set(res_exp[0])
# Out:
# ({4, 12, 16, 17, 20, 21, 24, 31, 32, 33, 37, 39},
#  {4, 12, 16, 17, 20, 21, 22, 24, 31, 32, 33, 37, 39},
#  {4, 12, 17, 20, 21, 31, 32, 33, 37, 39})

# %% [markdown]
# A better intuition can be gained by plotting the inputs corresponding to the *support-vectors* alongside the *data-vectors*. For the sake of better visualisation markers on the *support-vectors* are scaled according to their corresponding *alpha*.$\{\alpha_i\}$

# %%
split_xs = lambda x: [[x[i][j] for i in range(len(x))] for j in [0, 1]]
xi_sv , xj_sv = split_xs([X_train[i] for i in res_ideal[0] ])  ## change with {res_exp[0], res_exp[1], svc_sklrn.support_  }

sv_sizes = [res_ideal[1][i][1] *60 for i in range(len(res_ideal[0]))]
# sv_sizes = sv_sizes / np.sum(sv_sizes)

xi, xj = split_xs(Xs)
xi_train, xj_train = split_xs(X_train)
xi_test, xj_test = split_xs(X_test)

label_circle = mlines.Line2D(
    [],
    [],
    color="none",
    marker="o",
    markerfacecolor="none",
    markeredgecolor="black",
    label=f"Train ({len(X_train)})",
)
label_square = mlines.Line2D(
    [],
    [],
    color="none",
    marker="s",
    markerfacecolor="none",
    markeredgecolor="black",
    label=f"Test ({len(X_test)})",
)

plt.figure(figsize=(20,11))
plt.scatter(xi, xj, marker="o", c=["r" if v == 1.0 else "cyan" for v in Ys])
plt.scatter(xi_train, xj_train, c=["k" if v == 1.0 else "y" for v in Y_train], label="training data")
plt.scatter(xi_test, xj_test, marker="s", c=["k" if v == 1.0 else "y" for v in Y_test], label="test data")
plt.scatter(xi_sv, xj_sv, s= sv_sizes , marker="X", c = "g", label="Support vectors" )  ## the green markers indicate the support-vectors
plt.xticks([0, 2 * np.pi], [r"$0$", r"$2\pi$"])
plt.yticks([0, 2 * np.pi], [r"$0$", r"$2\pi$"])
plt.xlabel("$\\theta$")
plt.ylabel("$\phi$")
#plt.legend(handles=[label_circle, label_square], loc="upper right")
plt.legend()
plt.title(f"Classification Data Rz | $\Delta = {delta}$ | #(SV) = {len(res_ideal[0])} / {str(len(X_train))} | accuracy = {acc_ideal}%")
plt.show()

# %% [markdown]
# Looking at the support-vectors in the input-space might not clear how exactly they help in the classification process as they seem to be distributed rather randomly all over the innput space. But recall that the support-vectors come into action only when mapped to a higher-dimnesional feautre space and not necessarily in the input-spcae itself.

# %% [markdown]
# We know that during classification a data point $s$ is classified as $\tilde{m}(\textbf{s}) = \text{sign} \bigg(\sum_{i=1}^t y_i \alpha_i^* K(\textbf{x}_i, \textbf{s}) + b \bigg)$, so given a vector $s$ its label is more likely to be affected by a support vetor $x_s$ with a higher $\alpha$ than a support vector $\tilde{x}_s$ with a lower $\tilde{\alpha}$.
#
# Looking at the current plot you will find that most of the heavy support-vectors are located in the edges of the blob, which seems just as classifying such data-poitns would naturally be more difficult than a data-point located in middle of the blob.
#
# Another thing to notice is that out of 40 training-vectors only around 12-13 of them are included in the support, from our observations it reamins about the same for any instance of the data. In cases where this number fell below 10 the predection accuracy was affected accordingly.
#
#  For eg. in the current instance the support from the experimental-kernel has 10 elements compared to the support from the ideal-kernel which has 13 elements, which could explain that deprication of prediction accuracy of the former.

# %%
def powerset(iterable, mx):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    pset = chain.from_iterable(combinations(s, r) for r in range(len(s) + 1))
    return [l for l in list(pset) if len(l) == mx]
n_wires = 2  # number of qubits
S_size = 2  # number of interactions considered
depth = 2  # number of layers in ansatz
pset = powerset(range(n_wires), S_size)
def encode_data(x):
    """Non-linear encoding (transformation) of one input data vector

    Args:
        x : shape (2,) tensor containing one input data vector

    Returns:
        triple of data encoded coefficients phi_1, phi_2, phi_{1,2}
    """

    return x[0], x[1], (np.pi - x[0]) * (np.pi - x[1])
def feature_map(x):
    """Short depth feature map with entanglement

    Args:
        x : shape (3,) tensor containing one encoded data vector
    """
    for _ in range(2):
        qml.Hadamard(wires=0)
        qml.Hadamard(wires=1)
        qml.RZ(-2 * x[0], wires=0)
        qml.RZ(-2 * x[1], wires=1)
        qml.CNOT(wires=[0, 1])
        qml.RZ(-2 * x[2], wires=1)
        qml.CNOT(wires=[0, 1])
def ansatz(params):
    """VQC ansatz using single-qubits unitaries and entangling gates

    Args:
        params : shape (`depth` + 1, `n_wires`, 3) tensor containing trainable parameters
    """
    
    # for j in range(n_wires):
    #      qml.Rot(params[0, j, 0], params[0, j, 1], params[0, j, 2], wires=j)
    
    
    ## Made it 4 rotations to optimize instead of 6
    for i in range(0,depth):
        for s in pset:
            qml.CZ(wires=s)
            for j in range(n_wires):
                qml.Rot(params[i, j, 0], params[i, j, 1], params[i, j, 2], wires=j)
def circuit(params, x):
    """Havlicek et al. variational quantum circuit

    Args:
        params : shape (`depth` + 1, `n_wires`, 3) tensor containing trainable parameters
        x : shape (2,) tensor containing one input data vector

    Returns:
        shape(2 * 'n_wires',) tensor containing Z basis measurement probability on each qubit
    """

    feature_map(encode_data(x))  # prepare initial feature map state
    ansatz(params)  # apply discriminator circuit

    return qml.probs(wires=range(n_wires))  # p(+1), p(-1)
shots = 500  # number of circuit executions

dev_local = qml.device("default.qubit", wires=n_wires, shots=shots)

qnode_local = qml.QNode(circuit, dev_local)
# Load trained parameters
depth = 2
params_csv = "vqc/20221103-171829/RaFlaNeQ_params.csv"
loaded_params = np.loadtxt(params_csv)
final_params = loaded_params.reshape(depth, n_wires, 3)

# %%
probs_sv = [qnode_local(final_params, X_train[i]) for i in res_ideal[0]]
probs_sv = [ np.array([x[0]+x[3], x[1]+x[2]]) for x in probs_sv]

# %%
probs = [qnode_local(final_params, X_train[i]) for i in range(len(X_train)) if i not in res_ideal[0]]
probs = [ np.array([x[0]+x[3], x[1]+x[2]]) for x in probs]

# prob_vs_alpha = list([(probs[i][0]*np.log(1/probs[i][0] + probs[i][1]*np.log(1/probs[i][1])), res_ideal[1][i][1]) for i in range(len(probs))] )
# prob_vs_alpha

# %%
probs
# Out:
# [tensor([0.612, 0.388], requires_grad=True),
#  tensor([0.428, 0.572], requires_grad=True),
#  tensor([0.43, 0.57], requires_grad=True),
#  tensor([0.846, 0.154], requires_grad=True),
#  tensor([0.698, 0.302], requires_grad=True),
#  tensor([0.944, 0.056], requires_grad=True),
#  tensor([0.282, 0.718], requires_grad=True),
#  tensor([0.65, 0.35], requires_grad=True),
#  tensor([0.59, 0.41], requires_grad=True),
#  tensor([0.816, 0.184], requires_grad=True),
#  tensor([0.574, 0.426], requires_grad=True),
#  tensor([0.4, 0.6], requires_grad=True),
#  tensor([0.816, 0.184], requires_grad=True),
#  tensor([0.678, 0.322], requires_grad=True),
#  tensor([0.382, 0.618], requires_grad=True),
#  tensor([0.288, 0.712], requires_grad=True),
#  tensor([0.492, 0.508], requires_grad=True),
#  tensor([0.644, 0.356], requires_grad=True),
#  tensor([0.814, 0.186], requires_grad=True),
#  tensor([0.898, 0.102], requires_grad=True),
#  tensor([0.494, 0.506], requires_grad=True),
#  tensor([0.526, 0.474], requires_grad=True),
#  tensor([0.818, 0.182], requires_grad=True),
#  tensor([0.224, 0.776], requires_grad=True),
#  tensor([0.544, 0.456], requires_grad=True),
#  tensor([0.526, 0.474], requires_grad=True),
#  tensor([0.978, 0.022], requires_grad=True)]

# %%
probs_sv
# Out:
# [tensor([0.484, 0.516], requires_grad=True),
#  tensor([0.908, 0.092], requires_grad=True),
#  tensor([0.522, 0.478], requires_grad=True),
#  tensor([0.378, 0.622], requires_grad=True),
#  tensor([0.214, 0.786], requires_grad=True),
#  tensor([0.598, 0.402], requires_grad=True),
#  tensor([0.698, 0.302], requires_grad=True),
#  tensor([0.472, 0.528], requires_grad=True),
#  tensor([0.428, 0.572], requires_grad=True),
#  tensor([0.426, 0.574], requires_grad=True),
#  tensor([0.444, 0.556], requires_grad=True),
#  tensor([0.65, 0.35], requires_grad=True),
#  tensor([0.566, 0.434], requires_grad=True)]

# %%
bianry_entropy = lambda x : -1 * x[0] * np.log2(x[0]) + -1 * x[1] * np.log2(x[1])

# %%
[bianry_entropy(prob) for prob in probs ]
# Out:
# [tensor(0.96349674, requires_grad=True),
#  tensor(0.98499001, requires_grad=True),
#  tensor(0.98581504, requires_grad=True),
#  tensor(0.61976044, requires_grad=True),
#  tensor(0.88372196, requires_grad=True),
#  tensor(0.31135737, requires_grad=True),
#  tensor(0.85816166, requires_grad=True),
#  tensor(0.93406806, requires_grad=True),
#  tensor(0.97650047, requires_grad=True),
#  tensor(0.68874981, requires_grad=True),
#  tensor(0.98414141, requires_grad=True),
#  tensor(0.97095059, requires_grad=True),
#  tensor(0.68874981, requires_grad=True),
#  tensor(0.90654314, requires_grad=True),
#  tensor(0.95944232, requires_grad=True),
#  tensor(0.86612368, requires_grad=True),
#  tensor(0.99981533, requires_grad=True),
#  tensor(0.93931271, requires_grad=True),
#  tensor(0.69302837, requires_grad=True),
#  tensor(0.47530357, requires_grad=True),
#  tensor(0.99989612, requires_grad=True),
#  tensor(0.9980486, requires_grad=True),
#  tensor(0.68443281, requires_grad=True),
#  tensor(0.76740442, requires_grad=True),
#  tensor(0.99440665, requires_grad=True),
#  tensor(0.9980486, requires_grad=True),
#  tensor(0.15252733, requires_grad=True)]

# %%
bin_ent = [bianry_entropy(prob) for prob in probs ]
np.mean(bin_ent), np.var(bin_ent)
# Out:
# (0.8253628518859796, 0.04829488712942284)

# %%
bin_ent_sv = [bianry_entropy(prob) for prob in probs_sv ]
np.mean(bin_ent_sv), np.var(bin_ent_sv)
# Out:
# (0.9139803742861723, 0.022935254892866127)
